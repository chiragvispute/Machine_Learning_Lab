# %% [markdown]
# <a href="https://colab.research.google.com/github/Alka-vish/Machine-Learning-Lab/blob/main/Exp_9_Perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# 1. Load dataset
data = pd.read_csv('/content/drive/MyDrive/adult.csv')

# 2. Basic data cleaning
# Replace '?' with NaN
data = data.replace('?', np.nan)
data.dropna(inplace=True)  # drop rows with missing values

# 3. Separate features and target
X = data.drop('income', axis=1)
y = data['income']

# 4. Encode target variable
le = LabelEncoder()
y = le.fit_transform(y)  # '>50K' -> 1, '<=50K' -> 0

# 5. Identify categorical and numerical columns
categorical_cols = X.select_dtypes(include=['object']).columns.tolist()
numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns.tolist()

# 6. Preprocessing pipeline for categorical variables
# One-hot encode categorical variables, scale numerical variables
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
    ])

X_processed = preprocessor.fit_transform(X)

# 7. Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X_processed, y, test_size=0.2, random_state=42, stratify=y)

# 8. Build MLP model
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')  # binary classification
])

# 9. Compile model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 10. Train model
history = model.fit(X_train, y_train,
                    epochs=50,
                    batch_size=32,
                    validation_split=0.2,
                    verbose=2)

# 11. Evaluate model on test set
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"\nTest Accuracy: {test_acc:.4f}")

# 12. Optional: Predict and calculate accuracy manually
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)
print(f"Manual Accuracy Score: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 604/604 - 3s - 5ms/step - accuracy: 0.8294 - loss: 0.3623 - val_accuracy: 0.8512 - val_loss: 0.3247
# Epoch 2/50
# 604/604 - 3s - 5ms/step - accuracy: 0.8464 - loss: 0.3288 - val_accuracy: 0.8531 - val_loss: 0.3292
# Epoch 3/50
# 604/604 - 4s - 7ms/step - accuracy: 0.8487 - loss: 0.3218 - val_accuracy: 0.8543 - val_loss: 0.3215
# Epoch 4/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8520 - loss: 0.3181 - val_accuracy: 0.8498 - val_loss: 0.3224
# Epoch 5/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8534 - loss: 0.3147 - val_accuracy: 0.8510 - val_loss: 0.3245
# Epoch 6/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8549 - loss: 0.3109 - val_accuracy: 0.8539 - val_loss: 0.3244
# Epoch 7/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8579 - loss: 0.3096 - val_accuracy: 0.8564 - val_loss: 0.3247
# Epoch 8/50
# 604/604 - 3s - 5ms/step - accuracy: 0.8578 - loss: 0.3071 - val_accuracy: 0.8550 - val_loss: 0.3280
# Epoch 9/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8596 - loss: 0.3047 - val_accuracy: 0.8523 - val_loss: 0.3312
# Epoch 10/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8597 - loss: 0.3032 - val_accuracy: 0.8564 - val_loss: 0.3287
# Epoch 11/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8624 - loss: 0.2992 - val_accuracy: 0.8529 - val_loss: 0.3302
# Epoch 12/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8621 - loss: 0.2968 - val_accuracy: 0.8489 - val_loss: 0.3322
# Epoch 13/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8631 - loss: 0.2954 - val_accuracy: 0.8572 - val_loss: 0.3326
# Epoch 14/50
# 604/604 - 2s - 4ms/step - accuracy: 0.8641 - loss: 0.2933 - val_accuracy: 0.8537 - val_loss: 0.3368
# Epoch 15/50
# 604/604 - 3s - 5ms/step - accuracy: 0.8609 - loss: 0.2924 - val_accuracy: 0.8527 - val_loss: 0.3363
# Epoch 16/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8660 - loss: 0.2892 - val_accuracy: 0.8539 - val_loss: 0.3379
# Epoch 17/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8698 - loss: 0.2843 - val_accuracy: 0.8529 - val_loss: 0.3454
# Epoch 18/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8676 - loss: 0.2836 - val_accuracy: 0.8502 - val_loss: 0.3444
# Epoch 19/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8670 - loss: 0.2830 - val_accuracy: 0.8494 - val_loss: 0.3512
# Epoch 20/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8705 - loss: 0.2822 - val_accuracy: 0.8508 - val_loss: 0.3495
# Epoch 21/50
# 604/604 - 2s - 4ms/step - accuracy: 0.8675 - loss: 0.2798 - val_accuracy: 0.8475 - val_loss: 0.3585
# Epoch 22/50
# 604/604 - 3s - 4ms/step - accuracy: 0.8706 - loss: 0.2774 - val_accuracy: 0.8533 - val_loss: 0.3608
# Epoch 23/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8717 - loss: 0.2758 - val_accuracy: 0.8516 - val_loss: 0.3601
# Epoch 24/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8729 - loss: 0.2748 - val_accuracy: 0.8506 - val_loss: 0.3619
# Epoch 25/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8720 - loss: 0.2727 - val_accuracy: 0.8527 - val_loss: 0.3692
# Epoch 26/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8719 - loss: 0.2710 - val_accuracy: 0.8521 - val_loss: 0.3638
# Epoch 27/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8739 - loss: 0.2695 - val_accuracy: 0.8510 - val_loss: 0.3688
# Epoch 28/50
# 604/604 - 3s - 5ms/step - accuracy: 0.8762 - loss: 0.2659 - val_accuracy: 0.8500 - val_loss: 0.3825
# Epoch 29/50
# 604/604 - 2s - 4ms/step - accuracy: 0.8759 - loss: 0.2658 - val_accuracy: 0.8514 - val_loss: 0.3822
# Epoch 30/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8740 - loss: 0.2635 - val_accuracy: 0.8516 - val_loss: 0.3823
# Epoch 31/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8757 - loss: 0.2657 - val_accuracy: 0.8473 - val_loss: 0.3791
# Epoch 32/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8760 - loss: 0.2638 - val_accuracy: 0.8494 - val_loss: 0.3945
# Epoch 33/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8796 - loss: 0.2626 - val_accuracy: 0.8487 - val_loss: 0.3804
# Epoch 34/50
# 604/604 - 2s - 4ms/step - accuracy: 0.8739 - loss: 0.2614 - val_accuracy: 0.8471 - val_loss: 0.3950
# Epoch 35/50
# 604/604 - 3s - 5ms/step - accuracy: 0.8764 - loss: 0.2611 - val_accuracy: 0.8477 - val_loss: 0.3901
# Epoch 36/50
# 604/604 - 4s - 7ms/step - accuracy: 0.8774 - loss: 0.2611 - val_accuracy: 0.8500 - val_loss: 0.3989
# Epoch 37/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8776 - loss: 0.2592 - val_accuracy: 0.8492 - val_loss: 0.4009
# Epoch 38/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8784 - loss: 0.2536 - val_accuracy: 0.8502 - val_loss: 0.4004
# Epoch 39/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8777 - loss: 0.2580 - val_accuracy: 0.8492 - val_loss: 0.4042
# Epoch 40/50
# 604/604 - 3s - 4ms/step - accuracy: 0.8774 - loss: 0.2576 - val_accuracy: 0.8494 - val_loss: 0.4072
# Epoch 41/50
# 604/604 - 2s - 4ms/step - accuracy: 0.8801 - loss: 0.2587 - val_accuracy: 0.8500 - val_loss: 0.4074
# Epoch 42/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8799 - loss: 0.2533 - val_accuracy: 0.8465 - val_loss: 0.4090
# Epoch 43/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8787 - loss: 0.2533 - val_accuracy: 0.8487 - val_loss: 0.4128
# Epoch 44/50
# 604/604 - 3s - 4ms/step - accuracy: 0.8779 - loss: 0.2543 - val_accuracy: 0.8469 - val_loss: 0.4173
# Epoch 45/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8825 - loss: 0.2492 - val_accuracy: 0.8446 - val_loss: 0.4228
# Epoch 46/50
# 604/604 - 2s - 4ms/step - accuracy: 0.8788 - loss: 0.2498 - val_accuracy: 0.8462 - val_loss: 0.4209
# Epoch 47/50
# 604/604 - 3s - 5ms/step - accuracy: 0.8832 - loss: 0.2499 - val_accuracy: 0.8448 - val_loss: 0.4274
# Epoch 48/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8825 - loss: 0.2485 - val_accuracy: 0.8475 - val_loss: 0.4277
# Epoch 49/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8830 - loss: 0.2480 - val_accuracy: 0.8489 - val_loss: 0.4314
# Epoch 50/50
# 604/604 - 2s - 3ms/step - accuracy: 0.8810 - loss: 0.2474 - val_accuracy: 0.8456 - val_loss: 0.4312
#
# Test Accuracy: 0.8525
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Manual Accuracy Score: 0.8525

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import BatchNormalization

# 1. Load dataset
data = pd.read_csv('/content/drive/MyDrive/adult.csv')

# 2. Basic data cleaning
data = data.replace('?', np.nan)
data.dropna(inplace=True)

# 3. Separate features and target
X = data.drop('income', axis=1)
y = data['income']

# 4. Encode target variable
le = LabelEncoder()
y = le.fit_transform(y)

# 5. Identify categorical and numerical columns
categorical_cols = X.select_dtypes(include=['object']).columns.tolist()
numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns.tolist()

# 6. Preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
    ])

X_processed = preprocessor.fit_transform(X)

# 7. Split data
X_train, X_test, y_train, y_test = train_test_split(
    X_processed, y, test_size=0.2, random_state=42, stratify=y)

# 8. Build improved MLP model with L2 regularization and higher dropout
model = Sequential([
    Dense(128, activation='relu', kernel_regularizer=l2(0.001), input_shape=(X_train.shape[1],)),
    BatchNormalization(),
    Dropout(0.4),
    Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.4),
    Dense(1, activation='sigmoid')
])

# 9. Compile model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 10. Callbacks for early stopping and learning rate reduction
early_stop = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)

# 11. Train model with callbacks and larger batch size
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stop, reduce_lr],
    verbose=2
)

# 12. Evaluate on test set
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"\nTest Accuracy: {test_acc:.4f}")

# 13. Predict and calculate accuracy manually
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)
print(f"Manual Accuracy Score: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 302/302 - 4s - 12ms/step - accuracy: 0.7722 - loss: 0.6595 - val_accuracy: 0.8355 - val_loss: 0.4953 - learning_rate: 1.0000e-03
# Epoch 2/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8273 - loss: 0.5047 - val_accuracy: 0.8450 - val_loss: 0.4430 - learning_rate: 1.0000e-03
# Epoch 3/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8328 - loss: 0.4621 - val_accuracy: 0.8489 - val_loss: 0.4220 - learning_rate: 1.0000e-03
# Epoch 4/50
# 302/302 - 2s - 6ms/step - accuracy: 0.8385 - loss: 0.4329 - val_accuracy: 0.8498 - val_loss: 0.4044 - learning_rate: 1.0000e-03
# Epoch 5/50
# 302/302 - 2s - 6ms/step - accuracy: 0.8413 - loss: 0.4076 - val_accuracy: 0.8516 - val_loss: 0.3922 - learning_rate: 1.0000e-03
# Epoch 6/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8404 - loss: 0.3951 - val_accuracy: 0.8489 - val_loss: 0.3807 - learning_rate: 1.0000e-03
# Epoch 7/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8405 - loss: 0.3834 - val_accuracy: 0.8465 - val_loss: 0.3722 - learning_rate: 1.0000e-03
# Epoch 8/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8453 - loss: 0.3731 - val_accuracy: 0.8446 - val_loss: 0.3682 - learning_rate: 1.0000e-03
# Epoch 9/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8468 - loss: 0.3629 - val_accuracy: 0.8535 - val_loss: 0.3597 - learning_rate: 1.0000e-03
# Epoch 10/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8437 - loss: 0.3605 - val_accuracy: 0.8518 - val_loss: 0.3514 - learning_rate: 1.0000e-03
# Epoch 11/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8472 - loss: 0.3554 - val_accuracy: 0.8492 - val_loss: 0.3539 - learning_rate: 1.0000e-03
# Epoch 12/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8467 - loss: 0.3524 - val_accuracy: 0.8498 - val_loss: 0.3485 - learning_rate: 1.0000e-03
# Epoch 13/50
# 302/302 - 1s - 5ms/step - accuracy: 0.8446 - loss: 0.3516 - val_accuracy: 0.8440 - val_loss: 0.3529 - learning_rate: 1.0000e-03
# Epoch 14/50
# 302/302 - 2s - 6ms/step - accuracy: 0.8427 - loss: 0.3504 - val_accuracy: 0.8510 - val_loss: 0.3503 - learning_rate: 1.0000e-03
# Epoch 15/50
# 302/302 - 2s - 6ms/step - accuracy: 0.8476 - loss: 0.3454 - val_accuracy: 0.8550 - val_loss: 0.3451 - learning_rate: 1.0000e-03
# Epoch 16/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8477 - loss: 0.3461 - val_accuracy: 0.8500 - val_loss: 0.3484 - learning_rate: 1.0000e-03
# Epoch 17/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8485 - loss: 0.3411 - val_accuracy: 0.8537 - val_loss: 0.3439 - learning_rate: 1.0000e-03
# Epoch 18/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8480 - loss: 0.3440 - val_accuracy: 0.8525 - val_loss: 0.3413 - learning_rate: 1.0000e-03
# Epoch 19/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8489 - loss: 0.3404 - val_accuracy: 0.8506 - val_loss: 0.3498 - learning_rate: 1.0000e-03
# Epoch 20/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8491 - loss: 0.3388 - val_accuracy: 0.8518 - val_loss: 0.3428 - learning_rate: 1.0000e-03
# Epoch 21/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8452 - loss: 0.3445 - val_accuracy: 0.8564 - val_loss: 0.3394 - learning_rate: 1.0000e-03
# Epoch 22/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8490 - loss: 0.3401 - val_accuracy: 0.8529 - val_loss: 0.3400 - learning_rate: 1.0000e-03
# Epoch 23/50
# 302/302 - 2s - 6ms/step - accuracy: 0.8477 - loss: 0.3414 - val_accuracy: 0.8479 - val_loss: 0.3440 - learning_rate: 1.0000e-03
# Epoch 24/50
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 302/302 - 2s - 7ms/step - accuracy: 0.8498 - loss: 0.3424 - val_accuracy: 0.8512 - val_loss: 0.3433 - learning_rate: 1.0000e-03
# Epoch 25/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8510 - loss: 0.3345 - val_accuracy: 0.8533 - val_loss: 0.3392 - learning_rate: 5.0000e-04
# Epoch 26/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8518 - loss: 0.3314 - val_accuracy: 0.8545 - val_loss: 0.3415 - learning_rate: 5.0000e-04
# Epoch 27/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8524 - loss: 0.3317 - val_accuracy: 0.8527 - val_loss: 0.3389 - learning_rate: 5.0000e-04
# Epoch 28/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8543 - loss: 0.3279 - val_accuracy: 0.8547 - val_loss: 0.3377 - learning_rate: 5.0000e-04
# Epoch 29/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8531 - loss: 0.3305 - val_accuracy: 0.8545 - val_loss: 0.3379 - learning_rate: 5.0000e-04
# Epoch 30/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8552 - loss: 0.3262 - val_accuracy: 0.8556 - val_loss: 0.3398 - learning_rate: 5.0000e-04
# Epoch 31/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8539 - loss: 0.3269 - val_accuracy: 0.8545 - val_loss: 0.3365 - learning_rate: 5.0000e-04
# Epoch 32/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8570 - loss: 0.3221 - val_accuracy: 0.8535 - val_loss: 0.3373 - learning_rate: 5.0000e-04
# Epoch 33/50
# 302/302 - 2s - 6ms/step - accuracy: 0.8533 - loss: 0.3250 - val_accuracy: 0.8543 - val_loss: 0.3359 - learning_rate: 5.0000e-04
# Epoch 34/50
# 302/302 - 2s - 6ms/step - accuracy: 0.8542 - loss: 0.3248 - val_accuracy: 0.8514 - val_loss: 0.3386 - learning_rate: 5.0000e-04
# Epoch 35/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8530 - loss: 0.3242 - val_accuracy: 0.8527 - val_loss: 0.3396 - learning_rate: 5.0000e-04
# Epoch 36/50
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 302/302 - 1s - 4ms/step - accuracy: 0.8541 - loss: 0.3235 - val_accuracy: 0.8531 - val_loss: 0.3397 - learning_rate: 5.0000e-04
# Epoch 37/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8602 - loss: 0.3164 - val_accuracy: 0.8533 - val_loss: 0.3414 - learning_rate: 2.5000e-04
# Epoch 38/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8582 - loss: 0.3163 - val_accuracy: 0.8541 - val_loss: 0.3399 - learning_rate: 2.5000e-04
# Epoch 39/50
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 302/302 - 1s - 4ms/step - accuracy: 0.8606 - loss: 0.3132 - val_accuracy: 0.8514 - val_loss: 0.3398 - learning_rate: 2.5000e-04
# Epoch 40/50
# 302/302 - 1s - 4ms/step - accuracy: 0.8587 - loss: 0.3120 - val_accuracy: 0.8533 - val_loss: 0.3402 - learning_rate: 1.2500e-04
#
# Test Accuracy: 0.8623
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Manual Accuracy Score: 0.8623

# %%
new_sample = {
    'age': 37,
    'workclass': 'Private',
    'fnlwgt': 34146,
    'education': 'HS-grad',
    'education.num': 9,
    'marital.status': 'Married-civ-spouse',
    'occupation': 'Exec-managerial',
    'relationship': 'Husband',
    'race': 'White',
    'sex': 'Male',
    'capital.gain': 0,
    'capital.loss': 0,
    'hours.per.week': 40,
    'native.country': 'United-States'
}

# %%
import pandas as pd
import numpy as np

# Convert dict to DataFrame (single row)
input_df = pd.DataFrame([new_sample])

# Preprocess using the same pipeline
input_processed = preprocessor.transform(input_df)  # Use transform, NOT fit_transform

# %%
# Predict probability
pred_prob = model.predict(input_processed)

# Convert probability to class label (threshold 0.5)
pred_class = (pred_prob > 0.5).astype(int)

print(f"Predicted class: {pred_class[0][0]}, Probability: {pred_prob[0][0]:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Predicted class: 0, Probability: 0.3648
