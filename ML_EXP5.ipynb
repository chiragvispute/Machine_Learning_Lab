# %% [markdown]
# <a href="https://colab.research.google.com/github/Alka-vish/Machine-Learning-Lab/blob/main/Exp_5_Cross_Validation_Bias_Variance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/weatherHistory.csv')

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# Convert 'Formatted Date' to datetime format, handling mixed timezones
df['Formatted Date'] = pd.to_datetime(df['Formatted Date'], utc=True)

# Extract useful features from the datetime column
df['Hour'] = df['Formatted Date'].dt.hour
df['Day'] = df['Formatted Date'].dt.day

# Encode the 'Precip Type' as numbers if not already encoded
label_encoder = LabelEncoder()
df['Precip Type Encoded'] = label_encoder.fit_transform(df['Precip Type'])

# Define features and target
X = df[['Hour', 'Day', 'Humidity', 'Wind Speed (km/h)', 'Wind Bearing (degrees)',
        'Visibility (km)', 'Loud Cover', 'Pressure (millibars)', 'Temperature (C)']]
y = df['Precip Type Encoded']  # Target is now the precipitation type

# %%
df.head()
# Out:
#              Formatted Date        Summary  Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy            1         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy            1         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy            1         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy            1         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy            1         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

kf = KFold(n_splits=5, shuffle=True, random_state=42)

train_accuracies = []
test_accuracies = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    model = DecisionTreeClassifier(random_state=42, max_depth=5)  # limit tree depth to avoid overfitting
    model.fit(X_train, y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    train_acc = accuracy_score(y_train, y_train_pred)
    test_acc = accuracy_score(y_test, y_test_pred)

    train_accuracies.append(train_acc)
    test_accuracies.append(test_acc)

print("Train accuracies:", train_accuracies)
print("Test accuracies:", test_accuracies)
print(f"Average Train Accuracy: {np.mean(train_accuracies):.4f}")
print(f"Average Test Accuracy: {np.mean(test_accuracies):.4f}")
# Out:
# Train accuracies: [0.9962935123506389, 0.9959695186749955, 0.996189834374433, 0.9962546816479401, 0.9961250858572114]
# Test accuracies: [0.9955938002177182, 0.9969934166191489, 0.9957493131512104, 0.9955935717988595, 0.9961119751166407]
# Average Train Accuracy: 0.9962
# Average Test Accuracy: 0.9960

# %%
import numpy as np

# Step 6: Calculate average training and test errors (MSE)
avg_train_error = np.mean(train_errors)
avg_test_error = np.mean(test_errors)

# Output the results
print(f"Average Training Error (MSE): {avg_train_error:.4f}")
print(f"Average Test Error (MSE): {avg_test_error:.4f}")

# Step 7: Calculate Bias and Variance
# Bias is the average training error
bias = avg_train_error  # Higher bias means underfitting

# Variance is the difference between the average training error and test error
variance = avg_train_error - avg_test_error  # Higher variance means overfitting

print(f"Bias: {bias:.4f}")
print(f"Variance: {variance:.4f}")
# Out:
# Average Training Error (MSE): 29.4817
# Average Test Error (MSE): 29.7603
# Bias: 29.4817
# Variance: -0.2786

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

train_accuracies = []
test_accuracies = []

for train_idx, test_idx in kf.split(X):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    model = DecisionTreeClassifier(max_depth=5, random_state=42)
    model.fit(X_train, y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    train_acc = accuracy_score(y_train, y_train_pred)
    test_acc = accuracy_score(y_test, y_test_pred)

    train_accuracies.append(train_acc)
    test_accuracies.append(test_acc)

train_accuracies = np.array(train_accuracies)
test_accuracies = np.array(test_accuracies)

# Bias estimation: 1 - average training accuracy (error on training)
bias = 1 - train_accuracies.mean()

# Variance estimation: variance of test accuracies across folds
variance = test_accuracies.var()

print(f"Estimated Bias: {bias:.4f}")
print(f"Estimated Variance: {variance:.6f}")
# Out:
# Estimated Bias: 0.0038
# Estimated Variance: 0.000000
